# %%
import ibm_db

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://yjc26091:Wr2esVkDXIPH7t16@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB?security=SSL

# %%
# %%sql
# select * from imdb_movies
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('The Story of the Kelly Gang', 1906, 'Biography, Crime, Drama', 70, 'Australia', None, 'Charles Tait', 'Elizabeth Tait, John Tait, Norman Campbell, Bella Cola, Will Coyne, Sam Crewes, Jack Ennis, John Forde, Vera Linden, Mr. Marshall, Mr. McKenzie, Frank Mills, Ollie Wilson', Decimal('6.1'), 537),
#  ('Den sorte drøm', 1911, 'Drama', 53, 'Germany, Denmark', None, 'Urban Gad', 'Asta Nielsen, Valdemar Psilander, Gunnar Helsengreen, Emil Albes, Hugo Flink, Mary Hagen', Decimal('5.9'), 171),
#  ('Cleopatra', 1912, 'Drama, History', 100, 'USA', 'English', 'Charles L. Gaskill', 'Helen Gardner, Pearl Sindelar, Miss Fielding, Miss Robson, Helene Costello, Charles Sindelar, Mr. Howard, James R. Waite, Mr. Osborne, Harry Knowles, Mr. Paul, Mr. Brady, Mr. Corker', Decimal('5.2'), 420),
# ...

# %%
# %%sql
# select country,count(country) from imdb_movies group by country
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('Australia', 2),
#  ('Belgium', 1),
#  ('Canada', 1),
#  ('Denmark', 6),
#  ('France', 13),
#  ('France, Belgium', 1),
#  ('France, USA', 1),
#  ('Germany', 26),
#  ('Germany, Denmark', 2),
#  ('Hungary', 2),
#  ('Italy', 6),
#  ('Mexico', 1),
#  ('Norway', 2),
#  ('Romania', 1),
#  ('Russia', 4),
#  ('Sweden', 11),
#  ('USA', 130),
#  ('USA, Austria', 1)]

# %%
# %%sql
# select country, max(votes) from imdb_movies group by country
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('Australia', 537),
#  ('Belgium', 112),
#  ('Canada', 824),
#  ('Denmark', 1034),
#  ('France', 3936),
#  ('France, Belgium', 296),
#  ('France, USA', 211),
#  ('Germany', 51644),
#  ('Germany, Denmark', 277),
#  ('Hungary', 157),
#  ('Italy', 2838),
#  ('Mexico', 149),
#  ('Norway', 184),
#  ('Romania', 187),
#  ('Russia', 751),
#  ('Sweden', 1411),
#  ('USA', 20885),
#  ('USA, Austria', 1269)]

# %%
# %%sql
# select director, count(*) from imdb_movies group by director
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('Abel Gance', 2),
#  ('Alan Crosland', 1),
#  ('Albert Parker', 2),
#  ('Alexander Korda', 1),
#  ('Alfred Machin', 1),
#  ('Allan Dwan', 4),
#  ('André Antoine', 1),
#  ('André Calmettes, James Keane', 1),
#  ('Aristide Demetriade', 1),
#  ('Arthur Berthelet', 1),
#  ('August Blom', 1),
#  ('Benjamin Christensen', 2),
#  ('Carl Boese, Paul Wegener', 1),
#  ('Carl Theodor Dreyer', 3),
#  ('Cecil B. DeMille', 12),
#  ('Cecil B. DeMille, Joseph Levering', 1),
#  ('Charles Chaplin', 1),
#  ('Charles L. Gaskill', 1),
#  ('Charles Swickard, William S. Hart', 1),
#  ('Charles Tait', 1),
#  ('Chester M. Franklin, Sidney Franklin', 3),
#  ('Chester Withey', 1),
#  ('Christy Cabanne', 3),
#  ('Clarence Brown, Maurice Tourneur', 1),
#  ('D.W. Griffith', 12),
#  ('David Hartford', 2),
#  ('David Kirkland', 1),
#  ('Edgar Lewis', 1),
#  ('Edward S. Curtis', 1),
# ...

# %%
# %%sql
# select * from imdb_movies where actors like '%Murray%'
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('The Delicious Little Devil', 1919, 'Comedy, Drama', 63, 'USA', 'English', 'Robert Z. Leonard', "Mae Murray, Richard Cummings, Harry L. Rattenberry, Edward Jobson, Rudolph Valentino, Bert Woodruff, Martha Mattox, William V. Mong, Ivor McFadden, Bertram Grassby, Alice Knowland, I.S. McVea's Band, Satchel McVea", Decimal('6.0'), 801),
#  ('Yankee Doodle in Berlin', 1919, 'Comedy', 58, 'USA', 'English', 'F. Richard Jones', 'Bothwell Browne, Ford Sterling, Malcolm St. Clair, Bert Roach, Eva Thatcher, Marie Prevost, Ben Turpin, Charles Murray, Chester Conklin, Heinie Conklin, Joseph Belmont', Decimal('5.6'), 713)]

# %%
# %%sql
# select language, count(*) from imdb_movies group by language
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('Danish', 2),
#  ('English', 113),
#  ('English, German', 1),
#  ('French', 15),
#  ('German', 15),
#  ('German, English', 1),
#  ('Hungarian', 1),
#  ('Italian', 4),
#  ('Russian', 2),
#  ('Spanish', 1),
#  ('Swedish', 2),
#  ('Swedish, Danish', 1),
#  (None, 53)]

# %%
# %%sql
# select language, count(*) from imdb_movies where avg_vote > 7 group by language
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('English', 3),
#  ('French', 5),
#  ('German', 2),
#  ('Italian', 1),
#  ('Spanish', 1),
#  ('Swedish', 1),
#  ('Swedish, Danish', 1),
#  (None, 9)]

# %%
# %%sql
# select language, count(*) from imdb_movies where avg_vote>7 group by language having count>=2
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('English', 3), ('French', 5), ('German', 2), (None, 9)]
