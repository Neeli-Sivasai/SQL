# %%
import ibm_db

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://yjc26091:Wr2esVkDXIPH7t16@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB?security=SSL

# %%
# %%sql
# select * from cricket
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('Markram', 'Capetown', 450, 112),
#  ('Mayank Agarwal', 'Bangalore', 1000, 250),
#  ('Virat Kohli', 'Delhi', 10000, 180),
#  ('Ashwin', 'Chennai', 1000, 114)]

# %% [markdown]
# # Getting player with highest score using subqueries

# %%
# %%sql
# select batsman from cricket where highest in (select max(highest) from cricket)
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('Mayank Agarwal',)]

# %% [markdown]
# # Selecting multiple cricketers in all cricketers dataset

# %%
# %%sql
# select * from all_cricketers limit 10
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(1, 'SR Tendulkar (INDIA)', '1989-2012', 463, 452, 41, 18426, 200, Decimal('44.83'), 21367, Decimal('86.23'), 49, 96, 20),
#  (2, 'KC Sangakkara (Asia/ICC/SL)', '2000-2015', 404, 380, 41, 14234, 169, Decimal('41.98'), 18048, Decimal('78.86'), 25, 93, 15),
#  (3, 'RT Ponting (AUS/ICC)', '1995-2012', 375, 365, 39, 13704, 164, Decimal('42.03'), 17046, Decimal('80.39'), 30, 82, 20),
#  (4, 'ST Jayasuriya (Asia/SL)', '1989-2011', 445, 433, 18, 13430, 189, Decimal('32.36'), 14725, Decimal('91.20'), 28, 68, 34),
#  (5, 'DPMD Jayawardene (Asia/SL)', '1998-2015', 448, 418, 39, 12650, 144, Decimal('33.37'), 16020, Decimal('78.96'), 19, 77, 28),
#  (6, 'Inzamam-ul-Haq (Asia/PAK)', '1991-2007', 378, 350, 53, 11739, 137, Decimal('39.52'), 15812, Decimal('74.24'), 10, 83, 20),
# ...

# %%
# %%sql
# select * from all_cricketers order by mat  desc limit 10
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(1, 'SR Tendulkar (INDIA)', '1989-2012', 463, 452, 41, 18426, 200, Decimal('44.83'), 21367, Decimal('86.23'), 49, 96, 20),
#  (5, 'DPMD Jayawardene (Asia/SL)', '1998-2015', 448, 418, 39, 12650, 144, Decimal('33.37'), 16020, Decimal('78.96'), 19, 77, 28),
#  (4, 'ST Jayasuriya (Asia/SL)', '1989-2011', 445, 433, 18, 13430, 189, Decimal('32.36'), 14725, Decimal('91.20'), 28, 68, 34),
#  (2, 'KC Sangakkara (Asia/ICC/SL)', '2000-2015', 404, 380, 41, 14234, 169, Decimal('41.98'), 18048, Decimal('78.86'), 25, 93, 15),
#  (31, 'Shahid Afridi (Asia/ICC/PAK)', '1996-2015', 398, 369, 27, 8064, 124, Decimal('23.57'), 6892, Decimal('117.00'), 6, 39, 30),
#  (6, 'Inzamam-ul-Haq (Asia/PAK)', '1991-2007', 378, 350, 53, 11739, 137, Decimal('39.52'), 15812, Decimal('74.24'), 10, 83, 20),
# ...

# %%
# %%sql
# select * from all_cricketers where "duck" > 20
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(4, 'ST Jayasuriya (Asia/SL)', '1989-2011', 445, 433, 18, 13430, 189, Decimal('32.36'), 14725, Decimal('91.20'), 28, 68, 34),
#  (5, 'DPMD Jayawardene (Asia/SL)', '1998-2015', 448, 418, 39, 12650, 144, Decimal('33.37'), 16020, Decimal('78.96'), 19, 77, 28),
#  (12, 'CH Gayle (ICC/WI)', '1999-2019', 301, 294, 17, 10480, 215, Decimal('37.83'), 12019, Decimal('87.19'), 25, 54, 25),
#  (30, 'HH Gibbs (SA)', '1996-2010', 248, 240, 16, 8094, 175, Decimal('36.13'), 9721, Decimal('83.26'), 21, 37, 22),
#  (31, 'Shahid Afridi (Asia/ICC/PAK)', '1996-2015', 398, 369, 27, 8064, 124, Decimal('23.57'), 6892, Decimal('117.00'), 6, 39, 30),
#  (39, 'Younis Khan (PAK)', '2000-2015', 265, 255, 23, 7249, 144, Decimal('31.24'), 9628, Decimal('75.29'), 7, 48, 22),
# ...

# %%
# %%sql
# select * from all_cricketers where "centuries" > 20
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(1, 'SR Tendulkar (INDIA)', '1989-2012', 463, 452, 41, 18426, 200, Decimal('44.83'), 21367, Decimal('86.23'), 49, 96, 20),
#  (2, 'KC Sangakkara (Asia/ICC/SL)', '2000-2015', 404, 380, 41, 14234, 169, Decimal('41.98'), 18048, Decimal('78.86'), 25, 93, 15),
#  (3, 'RT Ponting (AUS/ICC)', '1995-2012', 375, 365, 39, 13704, 164, Decimal('42.03'), 17046, Decimal('80.39'), 30, 82, 20),
#  (4, 'ST Jayasuriya (Asia/SL)', '1989-2011', 445, 433, 18, 13430, 189, Decimal('32.36'), 14725, Decimal('91.20'), 28, 68, 34),
#  (7, 'V Kohli (INDIA)', '2008-2019', 242, 233, 39, 11609, 183, Decimal('59.84'), 12445, Decimal('93.28'), 43, 55, 13),
#  (9, 'SC Ganguly (Asia/INDIA)', '1992-2007', 311, 300, 23, 11363, 183, Decimal('41.02'), 15416, Decimal('73.70'), 22, 72, 16),
# ...

# %%
# %%sql
# select * from all_cricketers where "strikerate" > 100
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('AB de Villiers (Afr/SA)', '2005-2018', 228, 218, 39, 9577, 176, Decimal('53.50'), Decimal('101.09'), 25, 53, 7),
#  ('V Sehwag (Asia/ICC/INDIA)', '1999-2013', 251, 245, 9, 8273, 219, Decimal('35.05'), Decimal('104.33'), 15, 38, 14),
#  ('Shahid Afridi (Asia/ICC/PAK)', '1996-2015', 398, 369, 27, 8064, 124, Decimal('23.57'), Decimal('117.00'), 6, 39, 30),
#  ('JC Buttler (ENG)', '2012-2019', 142, 117, 23, 3843, 150, Decimal('40.88'), Decimal('119.83'), 9, 20, 12),
#  ('JJ Roy (ENG)', '2015-2019', 84, 81, 2, 3381, 180, Decimal('42.79'), Decimal('107.40'), 9, 18, 7),
#  ('DA Miller (SA)', '2010-2019', 126, 110, 31, 3058, 139, Decimal('38.70'), Decimal('100.13'), 5, 12, 8),
#  ('GJ Maxwell (AUS)', '2012-2019', 110, 100, 11, 2877, 102, Decimal('32.32'), Decimal('123.37'), 1, 19, 9),
# ...

# %%
# %%sql
# select * from all_cricketers
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('SR Tendulkar (INDIA)', '1989-2012', 463, 452, 41, 18426, 200, Decimal('44.83'), Decimal('86.23'), 49, 96, 20),
#  ('KC Sangakkara (Asia/ICC/SL)', '2000-2015', 404, 380, 41, 14234, 169, Decimal('41.98'), Decimal('78.86'), 25, 93, 15),
#  ('RT Ponting (AUS/ICC)', '1995-2012', 375, 365, 39, 13704, 164, Decimal('42.03'), Decimal('80.39'), 30, 82, 20),
#  ('ST Jayasuriya (Asia/SL)', '1989-2011', 445, 433, 18, 13430, 189, Decimal('32.36'), Decimal('91.20'), 28, 68, 34),
#  ('DPMD Jayawardene (Asia/SL)', '1998-2015', 448, 418, 39, 12650, 144, Decimal('33.37'), Decimal('78.96'), 19, 77, 28),
#  ('Inzamam-ul-Haq (Asia/PAK)', '1991-2007', 378, 350, 53, 11739, 137, Decimal('39.52'), Decimal('74.24'), 10, 83, 20),
#  ('V Kohli (INDIA)', '2008-2019', 242, 233, 39, 11609, 183, Decimal('59.84'), Decimal('93.28'), 43, 55, 13),
# ...

# %%
# %%sql
# select count("Matches") from all_cricketers
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(178,)]

# %%
# %%sql
# select * from all_cricketers where "duck" < 20 and "duck" >10
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('KC Sangakkara (Asia/ICC/SL)', '2000-2015', 404, 380, 41, 14234, 169, Decimal('41.98'), Decimal('78.86'), 25, 93, 15),
#  ('V Kohli (INDIA)', '2008-2019', 242, 233, 39, 11609, 183, Decimal('59.84'), Decimal('93.28'), 43, 55, 13),
#  ('JH Kallis (Afr/ICC/SA)', '1996-2014', 328, 314, 53, 11579, 139, Decimal('44.36'), Decimal('72.89'), 17, 86, 17),
#  ('SC Ganguly (Asia/INDIA)', '1992-2007', 311, 300, 23, 11363, 183, Decimal('41.02'), Decimal('73.70'), 22, 72, 16),
#  ('R Dravid (Asia/ICC/INDIA)', '1996-2011', 344, 318, 40, 10889, 153, Decimal('39.16'), Decimal('71.24'), 12, 83, 13),
#  ('BC Lara (ICC/WI)', '1990-2007', 299, 289, 32, 10405, 169, Decimal('40.48'), Decimal('79.51'), 19, 63, 16),
#  ('TM Dilshan (SL)', '1999-2016', 330, 303, 41, 10290, 161, Decimal('39.27'), Decimal('86.23'), 22, 47, 11),
# ...

# %%
# %%sql
# select * from all_cricketers where "Matches" > 400
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [('SR Tendulkar (INDIA)', '1989-2012', 463, 452, 18426, 200, Decimal('44.83'), Decimal('86.23'), 49, 96, 20),
#  ('KC Sangakkara (Asia/ICC/SL)', '2000-2015', 404, 380, 14234, 169, Decimal('41.98'), Decimal('78.86'), 25, 93, 15),
#  ('ST Jayasuriya (Asia/SL)', '1989-2011', 445, 433, 13430, 189, Decimal('32.36'), Decimal('91.20'), 28, 68, 34),
#  ('DPMD Jayawardene (Asia/SL)', '1998-2015', 448, 418, 12650, 144, Decimal('33.37'), Decimal('78.96'), 19, 77, 28)]

# %%
# %%sql
# ALTER TABLE ALL_CRICKETERS DROP COLUMN "Not Out"
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# []

# %%
# %%sql
# select count("strikerate") from all_cricketers
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(178,)]

# %%
# %%sql
# select count(distinct fifty) from all_cricketers
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# Done.
# [(61,)]

# %%
# %%sql
# select count(*) from all_cricketers
# Out:
#  * ibm_db_sa://yjc26091:***@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "SPAN" is not valid in the context where it is used.  SQLSTATE=42703\r SQLCODE=-206
# [SQL: select * from all_cricketers where span between '1989' and '2010']
# (Background on this error at: http://sqlalche.me/e/f405)
